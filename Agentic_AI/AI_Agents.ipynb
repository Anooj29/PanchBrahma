# %%
# !pip install pydantic-ai==0.1.3 pydantic-ai-slim[tavily]==0.1.3 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.7/152.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.5/301.5 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.4 MB/s eta 0:00:00
# ...

# %%
# pydantic is the library in order to create ai agents
# Trvily is a agentic search tool it integret with others platform

#Groq API key and tavily api key

# %%
 import nest_asyncio

 nest_asyncio.apply()

# %%
import os

from pydantic_ai.agent import Agent
from pydantic_ai.common_tools.tavily import tavily_search_tool

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
TAVILY_API_KEY = "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"

# %%
agent = Agent(
    'groq:llama-3.1-8b-instant',
    tools = [tavily_search_tool(TAVILY_API_KEY)],
    system_prompt='Search Tavily for the given query and return the results.'
)

# %%
result = agent.run_sync('Tell me the top news in the GenAI world recently.')
print(result.output)
# Out:
# The top news in the GenAI world recently includes:
#
# * Google contemplated exclusive Gemini AI deals with Android makers
# * Scientists improve gravitational wave identification with machine learning
# * Asymmetric molecular interactions may hold the secret to living matter
# * Big brains and big ranges might not save birds from climate change
# * CBA using AI as part of its 'big room planning'
#
# These news articles highlight the latest developments and advancements in the field of GenAI, including Google's plans to partner with Android makers, scientific breakthroughs in gravitational wave identification, and the potential secrets to living matter.
